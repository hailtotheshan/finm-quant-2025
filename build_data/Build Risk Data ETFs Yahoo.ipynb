# %%
import pandas as pd
import numpy as np

import yfinance as yf

# %%
TICKS = [
    'SPY',
    'VEA',
    'UPRO',
    'GLD',
    'USO',
    'FXE',
    'BTC-USD',
    'HYG',
    'IEF',
    'TIP',
    'SHV',
]

FLDS = ['quoteType','shortName','volume','totalAssets','longBusinessSummary']

# %%
info = pd.DataFrame(index=TICKS,columns=FLDS)
info.index.name = 'ticker'
for tick in info.index:
    temp = yf.Ticker(tick).get_info()

    for fld in FLDS:
        if fld in temp.keys():
            info.loc[tick,fld] = temp[fld]

# %%
prices = yf.download(TICKS, start="2017-01-01", end="2025-06-30")['Close'][info.index]
prices.rename(columns={'BTC-USD':'BTC', 'CL=F':'CL1'},inplace=True)
prices.dropna(inplace=True)
rets = prices.pct_change().dropna()
# Out:
# /var/folders/zx/3v_qt0957xzg3nqtnkv007d00000gn/T/ipykernel_22886/1186460500.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   prices = yf.download(TICKS, start="2017-01-01", end="2025-06-30")['Close'][info.index]
# [*********************100%***********************]  11 of 11 completed

# %%
info
# Out:
#               quoteType                        shortName       volume  \
# ticker
# SPY                 ETF                     SPDR S&P 500     91993247
# VEA                 ETF  Vanguard FTSE Developed Markets     14117842
# UPRO                ETF       ProShares UltraPro S&P 500      3575899
# GLD                 ETF                  SPDR Gold Trust      8046469
# USO                 ETF           United States Oil Fund      5910069
# FXE                 ETF  Invesco CurrencyShares Euro Cur       195591
# BTC-USD  CRYPTOCURRENCY                      Bitcoin USD  41706745856
# HYG                 ETF  iShares iBoxx $ High Yield Corp     49277832
# IEF                 ETF  iShares 7-10 Year Treasury Bond     10542291
# TIP                 ETF            iShares TIPS Bond ETF      4252748
# SHV                 ETF  iShares Short Treasury Bond ETF      3521474
#
#           totalAssets                                longBusinessSummary
# ticker
# SPY      603516960768  The trust seeks to achieve its investment obje...
# VEA      224745914368  The fund employs an indexing investment approa...
# UPRO       3852897280  The fund invests in financial instruments that...
# GLD       97988837376  The Trust holds gold bars and from time to tim...
# USO         907009344  USO invests primarily in futures contracts for...
# FXE         523996928                                                NaN
# BTC-USD           NaN                                                NaN
# HYG       15944028160  The underlying index is a rules-based index co...
# IEF       34938195968  The underlying index measures the performance ...
# TIP       13900867584  The index tracks the performance of inflation-...
# SHV       20599980032  The fund will invest at least 80% of its asset...

# %%
rets
# Out:
# Ticker           SPY       VEA      UPRO       GLD       USO       FXE  \
# Date
# 2017-01-04  0.005949  0.012238  0.017834  0.003530  0.012238  0.009314
# 2017-01-05 -0.000794  0.008866 -0.003057  0.015515  0.010363  0.010896
# 2017-01-06  0.003578 -0.003995  0.011323 -0.007373 -0.001709 -0.006700
# 2017-01-09 -0.003301 -0.002406 -0.009447  0.008233 -0.031678  0.003617
# 2017-01-10  0.000000  0.001072 -0.001648  0.004260 -0.021220 -0.001072
# ...              ...       ...       ...       ...       ...       ...
# 2025-06-23  0.009877  0.007636  0.029707  0.003063 -0.080727  0.005550
# 2025-06-24  0.011047  0.013172  0.033005 -0.015719 -0.044628  0.002994
# 2025-06-25  0.000560 -0.004987  0.001947  0.003037  0.004247  0.004011
# 2025-06-26  0.007824  0.010918  0.022657 -0.001107  0.003819  0.003995
# 2025-06-27  0.004968  0.006197  0.013495 -0.018124 -0.004212  0.000278
#
# Ticker           BTC       HYG       IEF       TIP       SHV
# Date
# 2017-01-04  0.106233  0.005408  0.001145  0.002207 -0.000090
# 2017-01-05 -0.122410 -0.001488  0.006484  0.003434 -0.000091
# 2017-01-06 -0.109711 -0.000229 -0.004547 -0.004125  0.000272
# 2017-01-09  0.000695 -0.000230  0.003807  0.001587  0.000181
# 2017-01-10  0.005373  0.000116 -0.000474  0.000792 -0.000091
# ...              ...       ...       ...       ...       ...
# 2025-06-23  0.021955  0.001880  0.003488  0.000823  0.000181
# 2025-06-24  0.004431  0.002752  0.003476  0.001280  0.000091
# 2025-06-25  0.012406 -0.000249  0.000420  0.000548  0.000091
# 2025-06-26 -0.003737  0.002870  0.003568  0.002920  0.000181
# 2025-06-27  0.001201 -0.000498 -0.002614 -0.001274  0.000362
#
# [2132 rows x 11 columns]

# %%
with pd.ExcelWriter('../data/risk_etf_data.xlsx') as writer:  
    info.to_excel(writer, sheet_name= 'descriptions')
    rets.to_excel(writer, sheet_name='total returns')
    prices.to_excel(writer, sheet_name='prices')

# %%
info
# Out:
#               quoteType                        shortName       volume  \
# ticker
# SPY                 ETF                     SPDR S&P 500     91993247
# VEA                 ETF  Vanguard FTSE Developed Markets     14117842
# UPRO                ETF       ProShares UltraPro S&P 500      3575899
# GLD                 ETF                  SPDR Gold Trust      8046469
# USO                 ETF           United States Oil Fund      5910069
# FXE                 ETF  Invesco CurrencyShares Euro Cur       195591
# BTC-USD  CRYPTOCURRENCY                      Bitcoin USD  41706745856
# HYG                 ETF  iShares iBoxx $ High Yield Corp     49277832
# IEF                 ETF  iShares 7-10 Year Treasury Bond     10542291
# TIP                 ETF            iShares TIPS Bond ETF      4252748
# SHV                 ETF  iShares Short Treasury Bond ETF      3521474
#
#           totalAssets                                longBusinessSummary
# ticker
# SPY      603516960768  The trust seeks to achieve its investment obje...
# VEA      224745914368  The fund employs an indexing investment approa...
# UPRO       3852897280  The fund invests in financial instruments that...
# GLD       97988837376  The Trust holds gold bars and from time to tim...
# USO         907009344  USO invests primarily in futures contracts for...
# FXE         523996928                                                NaN
# BTC-USD           NaN                                                NaN
# HYG       15944028160  The underlying index is a rules-based index co...
# IEF       34938195968  The underlying index measures the performance ...
# TIP       13900867584  The index tracks the performance of inflation-...
# SHV       20599980032  The fund will invest at least 80% of its asset...
